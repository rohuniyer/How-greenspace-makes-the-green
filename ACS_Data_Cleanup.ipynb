# %%
import pandas as pd

# %%
df = pd.read_csv('ACS_16_5YR_S0601.csv')
df.head()
# Out:
#                  GEO.id      GEO.id2  \
# 0                    Id          Id2
# 1  1400000US36061000100  36061000100
# 2  1400000US36061000201  36061000201
# 3  1400000US36061000202  36061000202
# 4  1400000US36061000500  36061000500
#
#                               GEO.display-label  \
# 0                                     Geography
# 1     Census Tract 1, New York County, New York
# 2  Census Tract 2.01, New York County, New York
# 3  Census Tract 2.02, New York County, New York
# 4     Census Tract 5, New York County, New York
#
#                        HC01_EST_VC01  \
# 0  Total; Estimate; Total population
# 1                                  0
# 2                               2670
# 3                               8016
# 4                                  0
#
#                               HC01_MOE_VC01  \
# 0  Total; Margin of Error; Total population
# 1                                        11
# 2                                       351
# ...

# %%
df.columns = df.iloc[0,:]
df = df.iloc[1:,:]
df = df.reset_index(drop=True)
df.head()
# Out:
# 0                    Id          Id2  \
# 0  1400000US36061000100  36061000100
# 1  1400000US36061000201  36061000201
# 2  1400000US36061000202  36061000202
# 3  1400000US36061000500  36061000500
# 4  1400000US36061000600  36061000600
#
# 0                                     Geography  \
# 0     Census Tract 1, New York County, New York
# 1  Census Tract 2.01, New York County, New York
# 2  Census Tract 2.02, New York County, New York
# 3     Census Tract 5, New York County, New York
# 4     Census Tract 6, New York County, New York
#
# 0 Total; Estimate; Total population Total; Margin of Error; Total population  \
# 0                                 0                                       11
# 1                              2670                                      351
# 2                              8016                                      564
# 3                                 0                                       11
# ...

# %% [markdown]
# ## Clean Census tract

# %%
def cleanCensusTract(x):
    """Cleans 'Geography' column into Census tract"""
    
    x_split = x.split(',')
    x_split = x_split[0].split(' ')
    return x_split[2]

# %%
df['censusTract'] = df.Geography.apply(lambda x: cleanCensusTract(x))

# %%
df.censusTract.value_counts()
# Out:
# 152       1
# 100       1
# 181       1
# 104       1
# 125       1
# 295       1
# 237       1
# 149       1
# 72        1
# 52        1
# 156.02    1
# 165       1
# 14.02     1
# 212       1
# 153       1
# 185       1
# 257       1
# 223.01    1
# 95        1
# 73        1
# 194       1
# 89        1
# 281       1
# 253       1
# 273       1
# 138       1
# 124       1
# 132       1
# 55.02     1
# 80        1
#          ..
# 98        1
# 142       1
# 38        1
# 148.01    1
# 214       1
# 37        1
# 173       1
# 61        1
# 114.01    1
# 8         1
# 230       1
# 283       1
# 267       1
# 88        1
# 146.01    1
# 31        1
# 28        1
# 215       1
# 130       1
# 187       1
# 239       1
# 227       1
# 197.01    1
# 184       1
# 5         1
# 177       1
# 36.01     1
# 236       1
# 263       1
# 113       1
# Name: censusTract, Length: 288, dtype: int64
